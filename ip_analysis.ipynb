# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import utils

# %%
df = pd.read_csv('ssh-logs.csv')

df[df.drop('fingerprint', axis=1).isna().any(axis=1)]
df.time = pd.to_datetime(df.time, format='%Y-%m-%dT%H:%M:%S', utc=True)
print(len(df), len(df.src.unique()))

thresh = 10

attack_counts = df.groupby('src').size()
ips_keep = attack_counts[attack_counts >= thresh].index
print(f'keeping {len(ips_keep)} out of {len(attack_counts)} ips')

df = df[np.isin(df.src, ips_keep)]

df_geo = utils.load_df_geo()
df = df.join(df_geo, 'src')

dt = utils.calculate_inter_attack_times(df)
df = df.join(dt)
# Out:
# 10015 4510
# keeping 46 out of 4510 ips

# %%
src = '119.252.161.redacted'
utils.print_text_features(df, src, top_n=3)
utils.plot_dt_density(df, src, t_max=100, fit=False)

plt.xlabel('inter-attack time')
plt.ylabel('density')
# Out:
# IP: 119.252.161.redacted
# origin: Tangerang, ID
# client_versions: ['SSH-2.0-libssh2_1.7.0']
# usernames: ['test', 'guest', 'user']
# passwords: ['123456', 'test', '1234']
# Text(0, 0.5, 'density')

# %%
src = '121.18.238.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=100, fit=True)
# Out:
# IP: 121.18.238.redacted
# origin: Shijiazhuang, CN
# client_versions: ['SSH-2.0-PUTTY']
# usernames: ['root']
# passwords: ['123456', 'root', 'password', 'root123', 'ubuntu']
# (82.23, 23.473)

# %%
src = '61.177.172.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=10)
# Out:
# IP: 61.177.172.redacted
# origin: Nanjing, CN
# client_versions: ['SSH-2.0-OpenSSH_6.2p2 Ubuntu-6', 'SSH-2.0-OpenSSH_5.3', 'SSH-2.0-nsssh2_4.0.0032 NetSarang Computer, Inc.', 'SSH-2.0-PuTTY']
# usernames: ['root']
# passwords: ['wubao', 'jiamima', 'admin', 't0talc0ntr0l4!', 'admin123']
# 89.45

# %%
src = '221.194.44.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=200, fit=True)
# Out:
# IP: 221.194.44.redacted
# origin: Shijiazhuang, CN
# client_versions: ['SSH-2.0-PUTTY']
# usernames: ['root']
# passwords: ['passwrod', 'root', '123456', 'password', 'ubuntu']
# (80.78, 33.564)

# %%
src = '42.7.26.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=200, fit=True)
# Out:
# IP: 42.7.26.redacted
# origin: Tianjin, CN
# client_versions: ['SSH-2.0-PUTTY']
# usernames: ['root']
# passwords: ['root', 'passwrod', 'ubuntu', 'password', '123456']
# (83.61, 24.186)

# %%
src = '221.194.47.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=200, fit=True)
# Out:
# IP: 221.194.47.redacted
# origin: Shijiazhuang, CN
# client_versions: ['SSH-2.0-PUTTY']
# usernames: ['root']
# passwords: ['123456', 'password', 'root', 'root123', 'passwrod']
# (80.84, 26.942)

# %%
src = '223.99.60.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=5)
# Out:
# IP: 223.99.60.redacted
# origin: Qingdao, CN
# client_versions: ['SSH-2.0-OpenSSH_6.2p2 Ubuntu-6']
# usernames: ['root']
# passwords: ['wubao', 'jiamima', 'admin', 'root']
# 95.57

# %%
src = '218.65.30.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=5)
# Out:
# IP: 218.65.30.redacted
# origin: Nanchang, CN
# client_versions: ['SSH-2.0-OpenSSH_6.2p2 Ubuntu-6', 'SSH-2.0-nsssh2_4.0.0032 NetSarang Computer, Inc.']
# usernames: ['root']
# passwords: ['wubao', 'admin', 'jiamima']
# 92.63

# %%
src = '59.63.166.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=5)
# Out:
# IP: 59.63.166.redacted
# origin: Nanchang, CN
# client_versions: ['SSH-2.0-OpenSSH_6.2p2 Ubuntu-6', 'SSH-2.0-nsssh2_4.0.0032 NetSarang Computer, Inc.']
# usernames: ['root']
# passwords: ['wubao']
# 95.38

# %%
src = '117.14.105.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=1000)
# Out:
# IP: 117.14.105.redacted
# origin: Tianjin, CN
# client_versions: ['SSH-2.0-Go']
# usernames: ['root', 'admin', 'user', 'service', '51732']
# passwords: ['root', '7ujm8ik,', 'god', 'openelec', 'user']
# 91.43

# %%
src = '119.249.54.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=200)
# Out:
# IP: 119.249.54.redacted
# origin: Jinrongjie, CN
# client_versions: ['SSH-2.0-PUTTY']
# usernames: ['root']
# passwords: ['root123', 'root', 'uniserver.root.2145', 'admin', 'letmein01']
# 85.71

# %%
src = '113.195.145.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=5)
# Out:
# IP: 113.195.145.redacted
# origin: Hefei, CN
# client_versions: ['SSH-2.0-OpenSSH_6.2p2 Ubuntu-6']
# usernames: ['root']
# passwords: ['wubao', 'jiamima']
# 94.12

# %%
src = '183.214.141.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=10)
# Out:
# IP: 183.214.141.redacted
# origin: Changsha, CN
# client_versions: ['SSH-2.0-OpenSSH_6.2p2 Ubuntu-6']
# usernames: ['root']
# passwords: ['wubao', 'jiamima', 'admin']
# 89.66

# %%
src = '164.132.19.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=200)
# Out:
# IP: 164.132.19.redacted
# origin: Argenteuil, FR
# client_versions: ['SSH-2.0-Go']
# usernames: ['root', 'admin', 'installer', 'backup', 'user']
# passwords: ['opnsense', 'qwertyuiop', 'mint', '4rfVgy7', '1qaz2wsx']
# 92.86

# %%
src = '218.87.109.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=5)
# Out:
# IP: 218.87.109.redacted
# origin: Nanchang, CN
# client_versions: ['SSH-2.0-OpenSSH_6.2p2 Ubuntu-6']
# usernames: ['root']
# passwords: ['wubao']
# 96.0

# %%
src = '115.238.94.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=500)
# Out:
# IP: 115.238.94.redacted
# origin: Hangzhou, CN
# client_versions: ['SSH-2.0-Go']
# usernames: ['root', 'admin', 'shipping', 'test', 'ftp']
# passwords: ['vizxv', '54321', 'asdfghjkl', 'apple', '7ujm8ik,']
# 95.24

# %%
src = '173.63.95.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=500)
# Out:
# IP: 173.63.95.redacted
# origin: Clifton, US
# client_versions: ['SSH-2.0-Go']
# usernames: ['root', 'admin', 'api', '666666', 'test']
# passwords: ['ubnt', 'api', '666666', '00000000', 'blowjob']
# 95.0

# %%
src = '117.164.152.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=500)
# Out:
# IP: 117.164.152.redacted
# origin: Zhanjiang, CN
# client_versions: ['SSH-2.0-Go']
# usernames: ['root', 'oiXgTCLYp', 'admin', 'user', 'fedora']
# passwords: ['XHywvdDr', '4rfVgy7', 'fedora', 'temppwd', 'klv1234']
# 84.21

# %%
src = '117.164.152.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=500)
# Out:
# IP: 117.164.152.redacted
# origin: Zhanjiang, CN
# client_versions: ['SSH-2.0-Go']
# usernames: ['root', 'oiXgTCLYp', 'admin', 'user', 'fedora']
# passwords: ['XHywvdDr', '4rfVgy7', 'fedora', 'temppwd', 'klv1234']
# 84.21

# %%
src = '46.173.214.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=500)
# Out:
# IP: 46.173.214.redacted
# origin: Vladimir, RU
# client_versions: ['SSH-2.0-Go']
# usernames: ['admin', 'root', 'user', 'ubuntu', 'nagios']
# passwords: ['root', 'beer', 'fuck', 'godblessamerica', 'meinsm']
# 82.35

# %%
src = '125.37.200.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=500)
# Out:
# IP: 125.37.200.redacted
# origin: Tianjin, CN
# client_versions: ['SSH-2.0-Go']
# usernames: ['root', 'admin', 'git', 'adolf', 'user1']
# passwords: ['1234', 'git', '4rfv5tgb', 'juantech', 'hitler']
# 82.35

# %%
src = '170.250.69.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=500)
# Out:
# IP: 170.250.69.redacted
# origin: Island Walk, US
# client_versions: ['SSH-2.0-Go']
# usernames: ['root', 'user', 'admin', 'putin', 'alDWAHDPYOzx']
# passwords: ['1qazse4', 'mint', '5tgb6yhn', 'vladimir', 'suse']
# 75.0

# %%
src = '178.20.227.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=500)
# Out:
# IP: 178.20.227.redacted
# origin: İzmir, TR
# client_versions: ['SSH-2.0-Go']
# usernames: ['admin', 'root', 'user', 'default', 'installer']
# passwords: ['default', 'kali', '4rfv5tgb', 'superman', 'user1234']
# 93.75

# %%
src = '198.24.146.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=600)
# Out:
# IP: 198.24.146.redacted
# origin: Phoenix, US
# client_versions: ['SSH-2.0-Go']
# usernames: ['root', 'user', 'admin', 'devel', 'operator']
# passwords: ['1234', 'whore', 'neon', 'devel', '2wsx3edc']
# 80.0

# %%
src = '182.18.254.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=500)
# Out:
# IP: 182.18.254.redacted
# origin: Quezon City, PH
# client_versions: ['SSH-2.0-Go']
# usernames: ['root', 'admin', 'donald', 'puppy', 'test']
# passwords: ['duck', 'centos', 'puppy', 'test', 'pos']
# 93.33

# %%
src = '111.162.230.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=500)
# Out:
# IP: 111.162.230.redacted
# origin: Tianjin, CN
# client_versions: ['SSH-2.0-Go']
# usernames: ['root', 'admin', 'svn', '70572', 'tech']
# passwords: ['2wsXdr5', '888888', 'manager', '4rfvgy7', '00000000']
# 86.67

# %%
src = '84.245.225.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=100000)
# Out:
# IP: 84.245.225.redacted
# origin: Riga, LV
# client_versions: ['SSH-2.0-Go']
# usernames: ['test', 'root', 'guest', 'centos', 'admin']
# passwords: ['12345678', 'erotic', 'firewall', 'rootme', 'brandy']
# 93.33

# %%
src = '101.51.123.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=100000)
# Out:
# IP: 101.51.123.redacted
# origin: Roi Et, TH
# client_versions: ['SSH-2.0-Go']
# usernames: ['root', 'user', 'admin', 'solus', 'user01']
# passwords: ['solus', 'system', '5tgBhu8', 'security', 'penis']
# 92.86

# %%
src = '182.100.67.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=10)
# Out:
# IP: 182.100.67.redacted
# origin: Pudong, CN
# client_versions: ['SSH-2.0-OpenSSH_6.2p2 Ubuntu-6']
# usernames: ['root']
# passwords: ['wubao', 'admin']
# 78.57

# %%
src = '99.14.31.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=100000)
# Out:
# IP: 99.14.31.redacted
# origin: Griffin, US
# client_versions: ['SSH-2.0-Go']
# usernames: ['admin', 'root', '9688', 'ftpuser', 'desktop']
# passwords: ['1qaZse4', 'fedora', 'abc123', 'rK2VV7Ku', 'internet']
# 92.31

# %%
src = '213.32.31.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=100000)
# Out:
# IP: 213.32.31.redacted
# origin: Gravelines, FR
# client_versions: ['SSH-2.0-Go']
# usernames: ['root', 'admin', 'demo', 'support']
# passwords: ['asdfghjkl', 'root', 'jesus', 'hacker', 'qwertyuiop']
# 92.31

# %%
src = '193.70.89.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=100000)
# Out:
# IP: 193.70.89.redacted
# origin: Roubaix, FR
# client_versions: ['SSH-2.0-Go']
# usernames: ['root', 'user', '576105', 'bill', 'shell']
# passwords: ['tails', '5tgb6yhn', 'XaLDZqDKY', 'gates', 'sh']
# 92.31

# %%
src = '122.15.164.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=500)
# Out:
# IP: 122.15.164.redacted
# origin: Mumbai, IN
# client_versions: ['SSH-2.0-Go']
# usernames: ['root', 'admin', '3062', 'oracle', '3139']
# passwords: ['qkAgajMGQXjWTdTHZ', 'oracle', '7ujMko0', 'putin', 'iphone']
# 84.62

# %%
src = '83.136.165.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=500)
# Out:
# IP: 83.136.165.redacted
# origin: Paris, FR
# client_versions: ['SSH-2.0-Go']
# usernames: ['svn', 'backup', 'root', 'fax', 'sales']
# passwords: ['svn', 'fax', 'sales', 'backup', '6yhNji9']
# 91.67

# %%
src = '118.212.135.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=500)
# Out:
# IP: 118.212.135.redacted
# origin: Nanchang, CN
# client_versions: ['SSH-2.0-OpenSSH_6.2p2 Ubuntu-6']
# usernames: ['root']
# passwords: ['wubao']
# 91.67

# %%
src = '202.87.35.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=500)
# Out:
# IP: 202.87.35.redacted
# origin: Mumbai, IN
# client_versions: ['SSH-2.0-Go']
# usernames: ['root', 'admin', '860634', 'nagios', 'monitor']
# passwords: ['football', 'OVyKDDflM', 'klv1234', 'openelec', 'nagios']
# 91.67

# %%
src = '222.85.224.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=500)
# Out:
# IP: 222.85.224.redacted
# origin: Guiyang, CN
# client_versions: ['SSH-2.0-Go']
# usernames: ['root', 'admin', 'fedora', 'user', 'adolf']
# passwords: ['putin', '123456', 'baseball', 'xc3511', 'default']
# 91.67

# %%
src = '187.242.35.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=500)
# Out:
# IP: 187.242.35.redacted
# origin: Victoria de Durango, MX
# client_versions: ['SSH-2.0-Go']
# usernames: ['root', 'user1', 'ilon', 'postgres', 'pi']
# passwords: ['1234', 'vagina', 'ubuntu', 'zentyal', 'godblessamerica']
# 83.33

# %%
src = '177.229.59.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=500)
# Out:
# IP: 177.229.59.redacted
# origin: Zacatepec, MX
# client_versions: ['SSH-2.0-Go']
# usernames: ['root', 'user', 'operator', '1.9', 'dev']
# passwords: ['blowjob', 'operator', 'SSH', 'solus', 'openelec']
# 72.73

# %%
src = '60.24.240.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=10000)
# Out:
# IP: 60.24.240.redacted
# origin: Tianjin, CN
# client_versions: ['SSH-2.0-Go']
# usernames: ['root', 'user1', 'pos', 'backup', '666666']
# passwords: ['mint', '123456', '5tgbhu8', 'mate', 'pos']
# 90.91

# %%
src = '192.168.2.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=10000)
# Out:
# IP: 192.168.2.redacted
# origin: nan, nan
# client_versions: ['SSH-2.0-Go', 'SSH-2.0-OpenSSH_6.9']
# usernames: ['root', 'phuong']
# passwords: ['secret', '999999', 'yahoo!', 'alibaba', 'phuong']
# 90.91

# %%
src = '164.132.109.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=10000)
# Out:
# IP: 164.132.109.redacted
# origin: Strasbourg, FR
# client_versions: ['SSH-2.0-Go']
# usernames: ['admin', 'root', 'user', 'docker', 'centos']
# passwords: ['quake', 'centos', 'god', '2wsx3edc', '7ujMko0admin']
# 90.91

# %%
src = '24.232.219.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=10000)
# Out:
# IP: 24.232.219.redacted
# origin: Córdoba, AR
# client_versions: ['SSH-2.0-Go']
# usernames: ['root', 'richard', 'user', 'admin', 'ubnt']
# passwords: ['1qazse4', 'cocaine', 'fout', 'mint', '123321']
# 90.0

# %%
src = '136.25.162.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=10000)
# Out:
# IP: 136.25.162.redacted
# origin: Berkeley, US
# client_versions: ['SSH-2.0-Go']
# usernames: ['root', 'user', 'admin', 'steam', '576105']
# passwords: ['password', 'vagina', '1qaz2wsx3EDC4RFV', '0987654321', 'same']
# 90.0

# %%
src = '113.6.252.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=10000)
# Out:
# IP: 113.6.252.redacted
# origin: Harbin, CN
# client_versions: ['SSH-2.0-Go']
# usernames: ['root', 'admin', 'kali', 'api']
# passwords: ['password123', '7ujm8ik,', 'satan', 'blowjob', 'korora']
# 90.0

# %%
src = '93.125.42.redacted'
utils.print_text_features(df, src)
utils.plot_dt_density(df, src, t_max=10000)
# Out:
# IP: 93.125.42.redacted
# origin: Minsk, BY
# client_versions: ['SSH-2.0-Go']
# usernames: ['admin', 'root', 'test', '3062', 'mail']
# passwords: ['5tgbhu8', 'test', 'qkAgajMGQXjWTdTHZ', '4rfVgy7', '0987654321']
# 90.0
